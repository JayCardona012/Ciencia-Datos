# %%
import pandas as pd

# %%
shopping = pd.read_csv("customer_shopping_data.csv")
shopping
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
shopping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
shopping.describe(include="all")
# Out:
#        invoice_no customer_id  gender           age  category      quantity  \
# count       99457       99457   99457  99457.000000     99457  99457.000000
# unique      99457       99457       2           NaN         8           NaN
# top       I138884     C241288  Female           NaN  Clothing           NaN
# freq            1           1   59482           NaN     34487           NaN
# mean          NaN         NaN     NaN     43.427089       NaN      3.003429
# std           NaN         NaN     NaN     14.990054       NaN      1.413025
# min           NaN         NaN     NaN     18.000000       NaN      1.000000
# 25%           NaN         NaN     NaN     30.000000       NaN      2.000000
# 50%           NaN         NaN     NaN     43.000000       NaN      3.000000
# 75%           NaN         NaN     NaN     56.000000       NaN      4.000000
# max           NaN         NaN     NaN     69.000000       NaN      5.000000
#
# ...

# %%
shopping.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
shopping.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
shopping.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
shopping.duplicated().sum()
shopping[shopping.duplicated()]
# Out:
# Empty DataFrame
# Columns: [invoice_no, customer_id, gender, age, category, quantity, price, payment_method, invoice_date, shopping_mall]
# Index: []

# %%
shopping["gender"].unique()
shopping["category"].unique()
shopping["payment_method"].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
shopping["age"]
shopping["quantity"]
shopping["price"]
shopping["invoice_no"]
# Out:
# 0        I138884
# 1        I317333
# 2        I127801
# 3        I173702
# 4        I337046
#           ...
# 99452    I219422
# 99453    I325143
# 99454    I824010
# 99455    I702964
# 99456    I232867
# Name: invoice_no, Length: 99457, dtype: object

# %%
customers = shopping[['customer_id', 'gender', 'age']].drop_duplicates()
customers.rename(columns={'customer_id': 'customers_id'}, inplace=True)
customers
# Out:
#       customers_id  gender  age
# 0          C241288  Female   28
# 1          C111565    Male   21
# 2          C266599    Male   20
# 3          C988172  Female   66
# 4          C189076  Female   53
# ...            ...     ...  ...
# 99452      C441542  Female   45
# 99453      C569580    Male   27
# 99454      C103292    Male   63
# 99455      C800631    Male   56
# 99456      C273973  Female   36
#
# [99457 rows x 3 columns]

# %%
categories = shopping[['category']].drop_duplicates()
categories['category_id'] = range(1, len(categories) + 1)
categories.rename(columns={'category': 'category_name'}, inplace=True)
categories
# Out:
#       category_name  category_id
# 0          Clothing            1
# 1             Shoes            2
# 4             Books            3
# 6         Cosmetics            4
# 10  Food & Beverage            5
# 12             Toys            6
# 23       Technology            7
# 67         Souvenir            8

# %%
payments = shopping[['payment_method']].drop_duplicates()
payments['payment_id'] = range(1, len(payments) + 1)
payments.rename(columns={'payment_method': 'payment_method'}, inplace=True)
payments
# Out:
#   payment_method  payment_id
# 0    Credit Card           1
# 1     Debit Card           2
# 2           Cash           3

# %%
malls = shopping[['shopping_mall']].drop_duplicates()
malls['shopping_mall_id'] = range(1, len(malls) + 1)
malls.rename(columns={'shopping_mall': 'mall_name'}, inplace=True)
malls
# Out:
#             mall_name  shopping_mall_id
# 0              Kanyon                 1
# 1      Forum Istanbul                 2
# 2           Metrocity                 3
# 3        Metropol AVM                 4
# 6        Istinye Park                 5
# 7    Mall of Istanbul                 6
# 11  Emaar Square Mall                 7
# 13        Cevahir AVM                 8
# 15     Viaport Outlet                 9
# 17       Zorlu Center                10

# %%
shopping['invoice_date'] = pd.to_datetime(shopping['invoice_date'], dayfirst=True)
dates = shopping[['invoice_date']].drop_duplicates()
dates['invoice_date_id'] = range(1, len(dates) + 1)
dates['year'] = dates['invoice_date'].dt.year
dates['month'] = dates['invoice_date'].dt.month
dates['day'] = dates['invoice_date'].dt.day
dates.rename(columns={'invoice_date': 'full_date'}, inplace=True)
dates
# Out:
#       full_date  invoice_date_id  year  month  day
# 0    2022-08-05                1  2022      8    5
# 1    2021-12-12                2  2021     12   12
# 2    2021-11-09                3  2021     11    9
# 3    2021-05-16                4  2021      5   16
# 4    2021-10-24                5  2021     10   24
# ...         ...              ...   ...    ...  ...
# 4220 2021-01-29              793  2021      1   29
# 4296 2021-01-01              794  2021      1    1
# 4491 2021-08-12              795  2021      8   12
# 4505 2022-01-08              796  2022      1    8
# 5173 2021-05-11              797  2021      5   11
#
# [797 rows x 5 columns]

# %%
invoices = shopping.merge(customers, left_on='customer_id', right_on='customers_id') \
                  .merge(categories, left_on='category', right_on='category_name') \
                  .merge(payments, left_on='payment_method', right_on='payment_method') \
                  .merge(malls, left_on='shopping_mall', right_on='mall_name') \
                  .merge(dates, left_on='invoice_date', right_on='full_date')
                  
invoices = invoices[['invoice_no', 'customers_id', 'category_id', 'payment_id', 'invoice_date_id', 'shopping_mall_id', 'quantity', 'price']]
invoices['total_price'] = invoices['quantity'] * invoices['price']
invoices.rename(columns={'invoice_no': 'invoice_detail_id'}, inplace=True)

invoices
# Out:
#       invoice_detail_id customers_id  category_id  payment_id  \
# 0               I138884      C241288            1           1
# 1               I317333      C111565            2           2
# 2               I127801      C266599            1           3
# 3               I173702      C988172            2           1
# 4               I337046      C189076            3           3
# ...                 ...          ...          ...         ...
# 99452           I219422      C441542            8           1
# 99453           I325143      C569580            5           3
# 99454           I824010      C103292            5           2
# 99455           I702964      C800631            7           3
# 99456           I232867      C273973            8           1
#
#        invoice_date_id  shopping_mall_id  quantity    price  total_price
# 0                    1                 1         5  1500.40      7502.00
# 1                    2                 2         3  1800.51      5401.53
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://neondb_owner:npg_uADsN2LoW8Zm@ep-sparkling-art-a8v6nquh-pooler.eastus2.azure.neon.tech/neondb?sslmode=require')

# %%
TABLE_CUSTOMERS = 'Customers'
TABLE_CATEGORIES = 'Categories'
TABLE_PAYMENTS = 'PaymentMethods'
TABLE_MALLS = 'ShoppingMalls'
TABLE_DATES = 'Dates'
TABLE_INVOICES = 'InvoiceDetails'

# %%
customers.to_sql(TABLE_CUSTOMERS, engine, if_exists='replace', index=False)
categories.to_sql(TABLE_CATEGORIES, engine, if_exists='replace', index=False)
payments.to_sql(TABLE_PAYMENTS, engine, if_exists='replace', index=False)
malls.to_sql(TABLE_MALLS, engine, if_exists='replace', index=False)
dates.to_sql(TABLE_DATES, engine, if_exists='replace', index=False)
invoices.to_sql(TABLE_INVOICES, engine, if_exists='replace', index=False)
# Out:
# 457

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ventas_por_categoria = shopping.groupby("category")["price"].sum().reset_index()
ventas_por_categoria.rename(columns={"price": "total_sales"}, inplace=True)


plt.figure(figsize=(10, 6))
sns.barplot(x="category", y="total_sales", data=ventas_por_categoria, palette="viridis")
plt.xlabel("Total Ventas")
plt.ylabel("Categoría")
plt.title("Total de Ventas por Categoría de Producto")
plt.show()
# Out:
# C:\Users\jayCg\AppData\Local\Temp\ipykernel_18384\1556050700.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="category", y="total_sales", data=ventas_por_categoria, palette="viridis")

# %%
clientes_top = shopping.groupby("customer_id")["price"].sum().reset_index()
clientes_top.rename(columns={"price": "total_spent"}, inplace=True)
clientes_top = clientes_top.sort_values("total_spent", ascending=False).head(10)

# 📊 Gráfico de barras horizontal - Clientes con más compras
plt.figure(figsize=(10, 5))
sns.barplot(x="total_spent", y="customer_id", data=clientes_top, palette="coolwarm", legend=True)
plt.xlabel("Total Gastado")
plt.ylabel("Cliente ID")
plt.title("Top 10 Clientes con Mayor Volumen de Compras")
plt.show()
# Out:
# C:\Users\jayCg\AppData\Local\Temp\ipykernel_18384\1317758732.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="total_spent", y="customer_id", data=clientes_top, palette="coolwarm", legend=True)

# %%
metodos_pago = shopping["payment_method"].value_counts().reset_index()
metodos_pago.columns = ["payment_method", "usage_count"]

# 🥧 Gráfico de torta - Métodos de pago más usados
plt.figure(figsize=(7, 7))
plt.pie(metodos_pago["usage_count"], labels=metodos_pago["payment_method"], autopct="%1.1f%%", colors=sns.color_palette("pastel"))
plt.title("Distribución de Métodos de Pago")
plt.show()

# %%
# Convertir invoice_date a tipo datetime
shopping["invoice_date"] = pd.to_datetime(shopping["invoice_date"], format="%d/%m/%Y")

ventas_por_mes = shopping.groupby(shopping["invoice_date"].dt.to_period("M"))["price"].sum().reset_index()
ventas_por_mes.rename(columns={"price": "total_sales"}, inplace=True)
ventas_por_mes["invoice_date"] = ventas_por_mes["invoice_date"].astype(str)  # Convertir a string para graficar

# 📈 Gráfico de líneas - Ventas por mes
plt.figure(figsize=(10, 5))
sns.lineplot(x="invoice_date", y="total_sales", data=ventas_por_mes, marker="o", linestyle="-")
plt.xticks(rotation=45)
plt.xlabel("Mes")
plt.ylabel("Total Ventas")
plt.title("Tendencia de Ventas por Mes")
plt.show()
